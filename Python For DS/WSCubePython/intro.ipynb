# %% [markdown]
# # **Python**
#
# ## **Defination:**
#
# *It is a genral purpose, interpreted, object oriented, high level programming language with dynamic sematics.*
#
#
#
# Interpreted mean it run code line by line.
#
# Object Oriented means it is works on classe and objects.
#
# High-Level means it is easy to understand and in simple english.
#
# Dynamic Sementics mean it can identify data types of variable run type. Not required to mention data type variable specially.
#
#
# ## **Features of Python :**
#
# 1) It is easy to learn & open source.
# 2) It has brod standard libararies.
# 3) Can supported for various operated system.
# 4) It is multiparadim language.
# 5) High-Level Programming language.
#
# ## **Application of Python :**
# 1) Data Analysis
# 2) Data Science
# 3) Web Application
# 4) Desktop Application
# 5) Game Development
# 6) Web Scrapping
# 7) ML & AI
