# %% [markdown]
# # **Variable in Python**
#
# *Varibles are the name in which we can store the values it acts as a container. And one more important think is when we create a variable value it has memory address in python but in other programming languages memory address for the name of variable.*

# %%
a1 = 1
print(a1)
# Out:
# 1

# %% [markdown]
# ## **Rules of variable creation:**
# 1) Variable name should not start with number.
# 2) Variable should not have space.
# 3) Variable cant have any special characters in starting expect underscore ( _ ).
#
# *In variables if the name of variables are same the values are getting updated downword direction codewise.*
