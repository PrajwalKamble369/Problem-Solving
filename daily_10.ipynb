# %% [markdown]
# ---
# ## **DAY 1 - Python Problem Solving**
# ### **Date 09/09/2026**

# %% [markdown]
# #### **Q1 — Positive, Negative or Zero**

# %%
number = float(input("Enter a Number you want to check that is +ve,-ve,0: "))
if number ==0:
    print(f"{number} is Zero")
elif number > 0:
    print(f"{number} is positive")
elif number < 0:
    print(f"{number} is negative")
else:
    print("Not identified")
# Out:
# 1.5 is positive

# %% [markdown]
# #### **Q2 — Even or Odd**

# %%
number = int(input("Enter Number: "))
if number % 2 == 0:
    print(f"{number} is even")
elif number % 2 != 0:
    print(f"{number} is odd")
else:
    print("Dont Know!")
# Out:
# 2 is even

# %% [markdown]
# #### **Q3 — Largest of Two Numbers**

# %%
num1 = float(input("Enter 1st number: "))
num2 = float(input("Enter 2nd number: "))
if num1 <  num2:
    print(f"{num2} is greater than {num1}")
else:
    print(f"{num1} is greater than {num2}")
# Out:
# 5.0 is greater than 3.0

# %% [markdown]
# #### **Q4 — Sum from 1 to N**

# %%
n = int(input("Enter a number: "))
s = 0
for i in range(1,n+1):
    s = s+ i
print(s)
# Out:
# 6

# %% [markdown]
# #### **Q5 — Count Even Numbers**

# %%
numbers = [2, 7, 10, 13, 18, 21]
c = 0
for i in numbers:
    if i % 2 ==0:
        c += 1
print(c)
# Out:
# 3

# %% [markdown]
# #### **Q6 — Reverse a String**

# %%
s = "python"
rt = "".join(reversed(s))
print(rt)
# Out:
# nohtyp

# %% [markdown]
# #### **Q7 — Count Vowels**

# %%
s = "machine learning"
c = 0
v = ["a", "e", "i", "o", "u"]
for i in s:
    if i in v:
        c += 1
print(c)
# Out:
# 6

# %% [markdown]
# #### **Q8 — Find Maximum in a List**

# %%
numbers = [12, 45, 7, 89, 23]
max = 0
for i in numbers:
    if i > max:
        max = i
print(max)
# Out:
# 89

# %% [markdown]
# #### **Q9 — Count Frequency ⭐**

# %%
numbers = [1, 2, 2, 3, 1, 2, 4, 3]
freq = {}
for i in numbers:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1
freq
# Out:
# {1: 2, 2: 3, 3: 2, 4: 1}

# %% [markdown]
# #### **Q10 — FizzBuzz 🧠**

# %%
# divisible by 3 --> Fizz
# divisible by 5 --> Buzz
# divisible by 3 and 5 --> FizzBuzz
# else --> number

num = int(input("Enter a number: "))
for i in range(1,num+1):
    if (i % 3 == 0) and (i %5 == 0):
        print("Fizz Buzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz") 
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz Buzz

# %% [markdown]
# ---
# ## **Day 2**
# ### **Date 10/09/2026**

# %% [markdown]
# #### **Q1 — Count Positive, Negative & Zero**
#
# ##### **Given a list of numbers, count how many are:**
#
# ###### **positive**
# ###### **negative**
# ###### **zero**
#
# ###### **Example:**
#
# ###### **numbers = [10, -5, 0, 7, -2, 0, 8]**

# %%
numbers = [10, -5, 0, 7, -2, 0, 8]
positive = 0
negative = 0
zero = 0
for i in numbers:
    if i >0:
        positive += 1
    elif i < 0:
        negative += 1
    else:
        zero +=1
print(positive,negative,zero)
# Out:
# 3 2 2

# %% [markdown]
# #### **Q2 — Sum of Even and Odd Numbers**
#
# ###### **Given a list, calculate separately:**
#
# ###### **sum of even numbers**
# ###### **sum of odd numbers**
#
# ###### **Example:**
#
# ###### **numbers = [1, 2, 3, 4, 5, 6]**

# %%
numbers = [1, 2, 3, 4, 5, 6]
sum_even = 0
sum_odd = 0
for i in numbers:
    if i % 2 == 0:
        sum_even += i
    else:
        sum_odd +=i
print(sum_even,sum_odd)
# Out:
# 12 9

# %% [markdown]
# #### **Q3 — Find the Smallest Number**
#
# ###### **Find the smallest number in a list without using min().**
#
# ###### **Test your code with:**
#
# ###### **numbers = [12, 5, 89, 3, 17, 1, 45]**

# %%
numbers = [12, 5, 89, 3, 17, 1, 45]
min_num = numbers[0]
for i in numbers:
    if i < min_num:
        min_num = i
print(min_num)
# Out:
# 1

# %% [markdown]
# #### **Q4 — Reverse a String Without reversed() or [::-1]**
#
# ###### **Given:**
#
# ###### **text = "developer"**

# %%
text = "developer"
r_t = ""
for i in range(len(text)-1,-1,-1):
    r_t += text[i]
print(r_t)
# Out:
# repoleved

# %% [markdown]
# #### **Q5 — Palindrome Checker**
#
# ###### **Write a program that checks whether a string is a palindrome.**
#
# ###### **Examples:**
#
# ###### **madam → Palindrome**
# ###### **python → Not Palindrome**
# ###### **level → Palindrome**

# %%
text = input("enter text: ").lower()
rt = text[::-1]
if text == rt:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %% [markdown]
# #### **Q6 — Remove Duplicates From a List**
#
# ###### **Given:**
#
# ###### **numbers = [1, 2, 2, 3, 4, 3, 5, 1, 6]**

# %%
numbers = [1, 2, 2, 3, 4, 3, 5, 1, 6]
unique_nums = []
for i in numbers:
    if i not in unique_nums:
        unique_nums.append(i)
print(unique_nums)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# #### **Q7 — Character Frequency ⭐**
#
# ###### **Given:**
#
#
# ###### **text = "banana"**

# %%
text = "banana"
freq ={}
for i in text:
    if i in freq:
        freq[i] +=1
    else:
        freq[i] = 1
freq
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %% [markdown]
# #### **Q8 — Second Largest Number 🧠**
#
# ###### **Given:**
#
# ###### **numbers = [10, 25, 7, 45, 32, 45, 18]**

# %%
numbers = [10, 25, 7, 45, 32, 45, 18]
max_num = max(numbers)
num_les_max = []
for i in numbers:
    if i < max_num:
        num_les_max.append(i)
print(max(num_les_max))
# Out:
# 32

# %% [markdown]
# #### **Q9 — Create a Function for Statistics**
#
# ###### **Write a function:**
#
# ###### **calculate_stats(numbers)**
#
# ###### **It should return:**
#
# ###### **minimum**
# ###### **maximum**
# ###### **average**
# ###### **count**
#
# ###### **For:**
#
# ###### **numbers = [10, 20, 30, 40, 50]**

# %%
def calculate_stats(numbers):
    minimum_num = min(numbers)
    maximum_num = max(numbers)
    average = sum(numbers)/len(numbers)
    count = len(numbers)
    return minimum_num, maximum_num, average, count
a = calculate_stats([10, 20, 30, 40, 50])
print(a)
# Out:
# (10, 50, 30.0, 5)

# %% [markdown]
# #### **Q10 — Simple ML Data Preprocessing 🧠🤖**
#
# ###### **Imagine these are student scores:**
#
# ###### **scores = [45, 78, 32, 90, 66, 55, 88, 40]**
#
# ###### **Create a program that:**
#
# ###### **Finds the average score.**
# ###### **Creates a new list containing only scores greater than or equal to the average.**
# ###### **Creates another list containing scores below the average.**
# ###### **Counts how many students are above/equal to average.**
# ###### **Counts how many are below average.**

# %%
scores = [45, 78, 32, 90, 66, 55, 88, 40]
def simple_ml(scores):
    avg_score = sum(scores)/len(scores)
    egavg_score = [i for i in scores if i >= avg_score]
    elavg_score = [i for i in scores if i < avg_score]
    ae_avg = len(egavg_score)
    ab_avg = len(elavg_score)
    return f"""
Average = {avg_score},
Greater than or equal to the average = {egavg_score},
Below the average = {elavg_score},
Count above/equal to average = {ae_avg},
Count below avg = {ab_avg}

"""

print(simple_ml([45, 78, 32, 90, 66, 55, 88, 40]))
# Out:
# Average = 61.75,
# Greater than or equal to the average = [78, 90, 66, 88],
# Below the average = [45, 32, 55, 40],
# Count above/equal to average = 4,
# Count below avg = 4

# %% [markdown]
# ---
# ## **Day 3 — Python Problem Solving**
# #### **Date 11/09/2026**

# %% [markdown]
# #### Q1 — Count Above, Below & Equal to Average
#
# ###### Given:
#
# ###### numbers = [10, 20, 15, 30, 25, 5]
#
# ###### Calculate the average, then count:
#
# ###### numbers greater than the average
# ###### numbers less than the average
# ###### numbers equal to the average

# %%
numbers = [10, 20, 15, 30, 25, 5]
avg = sum(numbers)/len(numbers)
greater_avg = []
less_than_avg = []
equal_to_avg = []
for i in numbers:
    if i > avg:
        greater_avg.append(i)
    elif i < avg:
        less_than_avg.append(i)
    elif i == equal_to_avg:
        equal_to_avg.append(i)
print(avg, greater_avg,less_than_avg,equal_to_avg)
# Out:
# 17.5 [20, 30, 25] [10, 15, 5] []

# %% [markdown]
# Q2 — Find Largest and Smallest Without Built-ins
#
# Given:
#
# numbers = [-10, 5, -2, 30, 7, -25, 15]
#
# Find both the largest and smallest numbers.
#
# Rules:
#
# Don't use max()
# Don't use min()
#
# Make sure your solution works when all numbers are negative.

# %%
numbers = [-10, 5, -2, 30, 7, -25, 15]
max_n = numbers[0]
min_n = numbers[0]
for i in numbers:
    if i > max_n:
        max_n = i
    elif i < min_n:
        min_n = i
print(max_n,min_n)
# Out:
# 30 -25

# %% [markdown]
# Q3 — Count Words Without split()
#
# Given:
#
# text = "python is useful for machine learning"
#
# Count the number of words without using split().
#
# Expected:
#
# 6

# %%
text = "python is useful for machine learning"

count = 0
in_word = False

for char in text:
    if char != " " and not in_word:
        count += 1
        in_word = True
    elif char == " ":
        in_word = False

print(count)
# Out:
# 6

# %% [markdown]
# Q4 — Reverse Each Word
#
# Given:
#
# text = "python machine learning"
#
# Produce:
#
# nohtyp enihcam gninrael
#
# Rules:
#
# You may use split()
# Don't use [::-1]
# Don't use reversed()

# %%
text = "python machine learning"

words = text.split()
result = []

for word in words:
    reversed_word = ""

    for i in range(len(word) - 1, -1, -1):
        reversed_word += word[i]

    result.append(reversed_word)

print(" ".join(result))
# Out:
# nohtyp enihcam gninrael

# %% [markdown]
# Q5 — Find Duplicate Numbers ⭐
#
# Given:
#
# numbers = [1, 2, 3, 2, 4, 5, 1, 6, 3, 3]
#
# Find all numbers appearing more than once.
#
# Expected:
#
# [1, 2, 3]

# %%
numbers = [1, 2, 3, 2, 4, 5, 1, 6, 3, 3]
freq = {}
for i in numbers:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] =1

n = []
for key, value in freq.items():
    if value > 1:
        n.append(key)
print(n)
# Out:
# [1, 2, 3]

# %% [markdown]
# Q6 — First Non-Repeating Character 🧠
#
# Given:
#
# text = "aabbcde"
#
# Find the first character that appears exactly once.
#
# Expected:
#
# c

# %%
text = "aabbcde"
freq = {}
for i in text:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1
for key, value in freq.items():
    if value == 1:
        print(key)
        break
# Out:
# c

# %% [markdown]
# Q7 — Common Elements Without Duplicates
#
# Given:
#
# list1 = [1, 2, 3, 4, 5, 3]
# list2 = [3, 4, 5, 6, 7, 3]
#
# Find the common elements.
#
# Expected:
#
# [3, 4, 5]

# %%
list1 = [1, 2, 3, 4, 5, 3]
list2 = [3, 4, 5, 6, 7, 3]
ul =[]
for i in list1:
    for j in list2:
        if i == j:
            ul.append(i)
ue= []
for i in ul:
    if i not in ue:
        ue.append(i)
print(ue)
# Out:
# [3, 4, 5]

# %% [markdown]
# Q8 — Second Smallest Distinct Number 🧠
#
# Given:
#
# numbers = [8, 3, 5, 3, 1, 9, 1, 4]
#
# Find the second-smallest distinct number.
#
# Expected:
#
# 3

# %%
numbers = [8, 3, 5, 3, 1, 9, 1, 4]

smallest = float("inf")
second_smallest = float("inf")

for num in numbers:

    if num < smallest:
        second_smallest = smallest
        smallest = num

    elif num > smallest and num < second_smallest:
        second_smallest = num

print(second_smallest)
# Out:
# 3

# %% [markdown]
# Q9 — Word Frequency Function 🤖
#
# Create:
#
# def word_frequency(text):
#     ...
#
# For:
#
# text = "Python is great and Python is powerful"
#
# Return a dictionary containing the frequency of each word.
#
# Expected conceptually:
#
# {
#     "python": 2,
#     "is": 2,
#     "great": 1,
#     "and": 1,
#     "powerful": 1
# }

# %%
def word_frequency(text):
    list_text = text.split()
    freq = {}
    for i in list_text:
        if i in freq:
            freq[i] += 1
        else:
            freq[i] = 1
    return freq
text = "Python is great and Python is powerful"
print(word_frequency(text))
# Out:
# {'Python': 2, 'is': 2, 'great': 1, 'and': 1, 'powerful': 1}

# %% [markdown]
# Q10 — Simple Prediction Thresholding 🤖🧠
#
# Imagine these are probabilities produced by an ML model:
#
# predictions = [0.2, 0.8, 0.45, 0.91, 0.67, 0.31, 0.55]
#
# Convert them into binary predictions:
#
# >= 0.5 → 1
# < 0.5  → 0

# %%
predictions = [0.2, 0.8, 0.45, 0.91, 0.67, 0.31, 0.55]
bin_cl = [1 if i >=0.5 else 0 for i in predictions]
# Out:
# [0, 1, 0, 1, 1, 0, 1]

# %% [markdown]
# ---
#
# #### **🐍 Day 4 — Python Problem Solving**
# ###### **Date 14/09/2026**

# %% [markdown]
# Q1 — Count Even, Odd & Negative Numbers
#
# numbers = [12, -5, 7, -8, 0, 14, -3, 9]
#
# Using one loop, count:
#
# positive even numbers
#
# positive odd numbers
#
# negative even numbers
#
# negative odd numbers
#
# zeros

# %%
numbers = [12, -5, 7, -8, 0, 14, -3, 9]

def Count_eon(numbers):
    p_even= 0
    n_even= 0
    p_odd = 0
    n_odd = 0 
    zeros = 0
  
    for i in numbers:
        if (i%2 == 0) and (i > 0):
            p_even += 1
        elif (i%2 == 0) and (i < 0):
            n_even += 1
        elif (i%2 != 0) and (i > 0):
            p_odd += 1
        elif (i%2 != 0) and (i < 0):
            n_odd += 1
        else:
            zeros +=1
    return f"""
Positive Even Number : {p_even}
Positive Odd Numbers : {p_odd}
Negative Even Numbers : {n_even}
Negative Odd Numbers : {n_odd}
Zeros: {zeros}

"""

a = Count_eon(numbers)
print(a)
# Out:
# Positive Even Number : 2
# Positive Odd Numbers : 2
# Negative Even Numbers : 1
# Negative Odd Numbers : 2
# Zeros: 4

# %% [markdown]
# Q2 — Filter by Threshold
#
# numbers = [45, 72, 31, 90, 66, 28, 81]
#
# threshold = 60
#
# Create a list containing numbers greater than or equal to the threshold.
#
# Then calculate how many numbers passed.

# %%
numbers = [45, 72, 31, 90, 66, 28, 81]
threshold = 60
threshold_list = []
for i in numbers:
    if i >= 60:
        threshold_list.append(i)
print(threshold_list)
# Out:
# [72, 90, 66, 81]

# %% [markdown]
# Q3 — Reverse a String Using a Loop
#
# text = "machine"
#
# Reverse the string without:
#
# [::-1]
# reversed()
#
# Expected:
#
# enihcam
#
# This reinforces the string-reversal pattern that challenged you on Day 3.

# %%
text = "machine"
rt = ""
for i in range(len(text)-1,-1,-1):
    rt += text[i]
print(rt)
# Out:
# enihcam

# %% [markdown]
# Q4 — Reverse Every Word
# text = "python is powerful"
#
# Expected:
#
# nohtyp si lufrewop
#
# Rules:
#
# You may use split()
# Don't use [::-1]
# Don't use reversed()

# %%
text = "python is powerful"
words = text.split()
reversed_word= []
for word in words:
    rev_word = ""
    for char in word:
        rev_word = char + rev_word
    reversed_word.append(rev_word)
result = " ".join(reversed_word)
print(result)
# Out:
# nohtyp si lufrewop

# %% [markdown]
# Q5 — Character Frequency + Most Frequent Character ⭐
# text = "programming"
#
# Create a dictionary containing the frequency of every character.
#
# Then find the character that occurs the most.
#
# Think carefully about what should happen if two characters have the same highest frequency.

# %%
text = "programming"
freq = {}
for i in text:
    if i in freq:
        freq[i] +=1
    else:
        freq[i] = 1
print(freq)

max_occ = 0
for keys, value in freq.items():
    if max_occ < value:
        max_occ = value

for keys, value in freq.items():
    if max_occ == value:
        print(keys) ## if more than one character have same maximum frqn then return all or even we can break if business demands it from us
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}
# r
# g
# m

# %% [markdown]
# Q6 — Remove Duplicate Words
# words = ["python", "ml", "python", "ai", "ml", "data"]
#
# Create a new list containing each word only once while preserving its original order.
#
# Expected:
#
# ["python", "ml", "ai", "data"]

# %%
words = ["python", "ml", "python", "ai", "ml", "data"]
uv= []
for i in words:
    if i not in uv:
        uv.append(i)
print(uv)
# Out:
# ['python', 'ml', 'ai', 'data']

# %% [markdown]
# numbers = [10, 25, 7, 45, 32, 45, 18]
#
# Find the second-largest distinct number.
#
# Expected:
#
# 32
#
# Don't use:
#
# max()
# sort()
# sorted()
#
# Try to solve it using two variables such as:
#
# largest
# second_largest

# %%
numbers = [10, 25, 7, 45, 32, 45, 18]

largest = numbers[0]
second_largest = numbers[0]

for num in numbers:

    if num > largest:
        second_largest = largest
        largest = num

    elif num < largest and num > second_largest:
        second_largest = num

print(second_largest)
# Out:
# 32

# %% [markdown]
# Q8 — Number Analysis Function
#
# Create:
#
# def analyze_numbers(numbers):
#     ...
#
# The function should return:
#
# minimum
# maximum
# average
# number of even values
# number of odd values
#
# For:
#
# [10, 15, 20, 25, 30]

# %%
def analyze_numbers(numbers):
    minimum = min(numbers)
    maximum = max(numbers)
    avg = sum(numbers)/ len(numbers)
    even_count = 0
    odd_count = 0
    for i in numbers:
        if i % 2 == 0:
            even_count +=1
        else:
            odd_count +=1

    return f"""
minimum = {minimum}
maximum = {maximum}
average = {avg}
even = {even_count}
odd = {odd_count}

"""

numbers = [10, 15, 20, 25, 30]

print(analyze_numbers(numbers))
# Out:
# minimum = 10
# maximum = 30
# average = 20.0
# even = 3
# odd = 2

# %% [markdown]
# Q9 — ML Prediction Filtering 🤖
#
# Suppose these are probabilities produced by a model:
#
# predictions = [0.23, 0.81, 0.45, 0.92, 0.67, 0.34, 0.76]
# threshold = 0.60
#
# Create:
#
# accepted → probabilities >= threshold
# rejected → probabilities < threshold
# accepted count
# rejected count
#
# Then calculate the percentage of predictions accepted.

# %%
predictions = [0.23, 0.81, 0.45, 0.92, 0.67, 0.34, 0.76]
threshold = 0.60

list_ar= ["accepted" if i >=threshold else "rejected" for i in predictions ]

rc = 0
ac = 0
for i in list_ar:
    if i == 'accepted':
        ac +=1
    else:
        rc += 1
print(rc,ac)
p_ap = (ac/ len(list_ar)) * 100
print(p_ap)
# Out:
# 3 4
# 57.14285714285714

# %% [markdown]
# Q10 — Simple Feature Transformation 🤖🧠
#
# Suppose you have:
#
# ages = [18, 25, 32, 45, 60]
#
# Create a new list where each age is transformed using:
#
# age / 100
#
# Expected:
#
# [0.18, 0.25, 0.32, 0.45, 0.60]
#
# Then create:
#
# def normalize_age(ages):
#     ...
#
# The function should perform the transformation for any list of ages.
#
# Test it with:
#
# [20, 30, 40, 50]

# %%
def normalize_age(ages):
    n_age = []
    for i in ages:
        n_age.append(i/100)
    return n_age

print(normalize_age([20, 30, 40, 50]))
# Out:
# [0.2, 0.3, 0.4, 0.5]

# %% [markdown]
# ## 🐍 Day 5 — Python Problem Solving
# #### 15 September 2026

# %% [markdown]
# Q1 — Number Classification
#
# Given:
#
# numbers = [12, -5, 0, 7, -8, 14, -3, 0, 9]
#
# Using one loop, count:
#
# positive numbers
# negative numbers
# zeros
# even numbers
# odd numbers

# %%
numbers = [12, -5, 0, 7, -8, 14, -3, 0, 9]
positive_numbers = 0
negative_numbers = 0
zeros = 0
even_numbers = 0
odd_numbers = 0

for i in numbers:
    if i % 2 ==0:
        even_numbers +=1
        if i > 0:
            positive_numbers +=1

        elif i== 0:
             zeros +=1

        else:
            negative_numbers +=1
       
    else:
        odd_numbers +=1
        if i > 0:
                positive_numbers +=1

        elif i == 0:
             zeros += 1

        else:
            negative_numbers +=1
            
print(positive_numbers,negative_numbers,zeros,even_numbers,positive_numbers)
# Out:
# 4 3 2 5 4

# %% [markdown]
# Q2 — Find the Smallest Number
#
# Given:
#
# numbers = [45, 12, 78, 3, 29, 61]
#
# Find the smallest number without using min().
#
# Then modify your logic so it also works correctly for:
#
# numbers = [-5, -12, -3, -20, -8]
#
# Think carefully about how you initialize your smallest value

# %%
numbers = [-5, -12, -3, -20, -8]
min_num = numbers[0]
for i in numbers:
    if i < min_num:
        min_num = i
print(min_num)
# Out:
# -20

# %%
numbers = [8, 3, 5, 3, 1, 9, 1, 4]

smallest = float("inf")
second_smallest = float("inf")

for num in numbers:

    if num < smallest:
        second_smallest = smallest
        smallest = num

    elif num > smallest and num < second_smallest:
        second_smallest = num

print(second_smallest)
# Out:
# 3

# %% [markdown]
# Q4 — Word Length Analysis
#
# Given:
#
# text = "python machine learning model"
#
# Split the sentence into words and determine:
#
# longest word
# shortest word
# length of longest word
# length of shortest word
#
# Expected:
#
# Longest: learning
# Shortest: model

# %%
text = "python machine learning model"
text_split = text.split()

word_len = []
for i in text_split:
    word_len.append(len(i))

max_len = word_len[0]
max_index = 0

min_len = word_len[0]
min_index = 0

for index, length in enumerate(word_len):
    if length > max_len:
        max_len = length
        max_index = index
    elif length < min_len:
        min_len = length
        min_index = index
print("Longest Word: ", text_split[max_index])
print("Shortest Word: ", text_split[min_index])
print(max_len)
print(min_len)
# Out:
# Longest Word:  learning
# Shortest Word:  model
# 8
# 5

# %% [markdown]
# Q5 — Dictionary: Count Positive/Negative Values ⭐
#
# Given:
#
# numbers = [10, -5, 7, -2, 10, -5, 10]
#
# Create a dictionary containing the frequency of each number.
#
# Then create another dictionary:
#
# {
#     "positive": ...,
#     "negative": ...,
#     "zero": ...
# }

# %%
numbers = [10, -5, 7, -2, 10, -5, 10]
freq = {}
for i in numbers:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1

summary_dict = {"positive":0, "negative":0,"zero":0}

for key, value in freq.items():
    if key > 0:
        summary_dict["positive"] += value
    elif key < 0:
        summary_dict["negative"] += value
    else:
        summary_dict["zero"] += value

print(summary_dict)
# Out:
# {'positive': 4, 'negative': 3, 'zero': 0}

# %% [markdown]
# Q6 — Function: Safe Average
#
# Create:
#
# def calculate_average(numbers):
#     ...
#
# The function should return the average of the numbers.
#
# For:
#
# [10, 20, 30, 40]
#
# return:
#
# 25.0
#
# But your function must also handle:
#
# []
#
# without causing a division-by-zero error.
# Decide what a sensible return value should be for an empty list.

# %%
def calculate_average(numbers):
    length = len(numbers)
    if length == 0:
        raise ZeroDivisionError("Cannot calculate the avg")
    return sum(numbers)/length
print(calculate_average([1,2,3,4]))
# Out:
# 5.0
